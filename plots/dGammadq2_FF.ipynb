# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
arr1 = np.genfromtxt('BDenu_ISGW2.csv')
arr2 = np.genfromtxt('BDenu_CLN.csv')

mpl.rcParams.update({'font.size': 20});

fig = plt.figure(figsize=(6*1.618, 6));
ax = fig.add_subplot(1,1,1);
ax.plot(arr1[:,0], arr1[:,1], '-', label='ISGW2');
ax.plot(arr2[:,0], arr2[:,1], '-', label='CLN');
ax.set_xlabel(r'$q^2$ (GeV)');
ax.set_ylabel(r'density');
plt.legend(fontsize=16);
fig.suptitle(r'$d\Gamma/dq^2$ for $B\rightarrow De\nu$');

# %%
arr1 = np.genfromtxt('BDmunu_ISGW2.csv')
arr2 = np.genfromtxt('BDmunu_CLN.csv')

mpl.rcParams.update({'font.size': 20});

fig = plt.figure(figsize=(6*1.618, 6));
ax = fig.add_subplot(1,1,1);
ax.plot(arr1[:,0], arr1[:,1], '-', label='ISGW2');
ax.plot(arr2[:,0], arr2[:,1], '-', label='CLN');
ax.set_xlabel(r'$q^2$ (GeV)');
ax.set_ylabel(r'density');
plt.legend(fontsize=16);
fig.suptitle(r'$d\Gamma/dq^2$ for $B\rightarrow D\mu\nu$');

# %%
arr1 = np.genfromtxt('BDtaunu_ISGW2.csv')
arr2 = np.genfromtxt('BDtaunu_CLN.csv')

mpl.rcParams.update({'font.size': 20});

fig = plt.figure(figsize=(6*1.618, 6));
ax = fig.add_subplot(1,1,1);
ax.plot(arr1[:,0], arr1[:,1], '-', label='ISGW2');
ax.plot(arr2[:,0], arr2[:,1], '-', label='CLN');
ax.set_xlabel(r'$q^2$ (GeV)');
ax.set_ylabel(r'density');
plt.legend(fontsize=16);
fig.suptitle(r'$d\Gamma/dq^2$ for $B\rightarrow D\tau\nu$');

# %%
arr1 = np.genfromtxt('BDsenu_Dpi_lminus_ISGW2.csv')
arr2 = np.genfromtxt('BDsenu_Dpi_lminus_CLN.csv')
arr3 = np.genfromtxt('BDsenu_Dpi_lminus_LinearQ2.csv')

mpl.rcParams.update({'font.size': 20});

fig = plt.figure(figsize=(6*1.618, 6));
ax = fig.add_subplot(1,1,1);
ax.plot(arr1[:,0], arr1[:,1], '-', label=r'ISGW2');
ax.plot(arr2[:,0], arr2[:,1], '-', label=r'CLN');
ax.plot(arr3[:,0], arr3[:,1], '-', label=r'LinearQ2');
ax.set_xlabel(r'$q^2$ (GeV)');
ax.set_ylabel(r'density');
plt.legend(fontsize=16, loc=3);
fig.suptitle(r'$d\Gamma/dq^2$ for $B\rightarrow D^*e^+\nu$, $D^*\rightarrow D\pi$');

# %%
arr1 = np.genfromtxt('BDsmunu_Dpi_lminus_ISGW2.csv')
arr2 = np.genfromtxt('BDsmunu_Dpi_lminus_CLN.csv')
arr3 = np.genfromtxt('BDsmunu_Dpi_lminus_LinearQ2.csv')

mpl.rcParams.update({'font.size': 20});

fig = plt.figure(figsize=(6*1.618, 6));
ax = fig.add_subplot(1,1,1);
ax.plot(arr1[:,0], arr1[:,1], '-', label=r'ISGW2');
ax.plot(arr2[:,0], arr2[:,1], '-', label=r'CLN');
ax.plot(arr3[:,0], arr3[:,1], '-', label=r'LinearQ2');
ax.set_xlabel(r'$q^2$ (GeV)');
ax.set_ylabel(r'density');
plt.legend(fontsize=16, loc=3);
fig.suptitle(r'$d\Gamma/dq^2$ for $B\rightarrow D^*\mu^+\nu$, $D^*\rightarrow D\pi$');

# %%
arr1 = np.genfromtxt('BDstaunu_Dpi_lminus_ISGW2.csv')
arr2 = np.genfromtxt('BDstaunu_Dpi_lminus_CLN.csv')
arr3 = np.genfromtxt('BDstaunu_Dpi_lminus_LinearQ2.csv')

mpl.rcParams.update({'font.size': 20});

fig = plt.figure(figsize=(6*1.618, 6));
ax = fig.add_subplot(1,1,1);
ax.plot(arr1[:,0], arr1[:,1], '-', label=r'ISGW2');
ax.plot(arr2[:,0], arr2[:,1], '-', label=r'CLN');
ax.plot(arr3[:,0], arr3[:,1], '-', label=r'LinearQ2');
ax.set_xlabel(r'$q^2$ (GeV)');
ax.set_ylabel(r'density');
plt.legend(fontsize=16, loc=2);
fig.suptitle(r'$d\Gamma/dq^2$ for $B\rightarrow D^*\tau^+\nu$, $D^*\rightarrow D\pi$');
